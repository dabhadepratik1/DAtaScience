# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
! ls
# Out:
# drive  sample_data

# %%
# %cd /content/drive/MyDrive/Colab Notebooks/DSCT
# Out:
# /content/drive/MyDrive/Colab Notebooks/DSCT

# %%
! git init
# Out:
# Initialized empty Git repository in /content/drive/MyDrive/Colab Notebooks/DSCT/.git/

# %%
username="dabhadepratik1"
repository="DataScience"
git_token="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"

# %%
# !git remote add origin https://{git_token}@github.com/{username}/{repository}.git
# Out:
# fatal: remote origin already exists.

# %%
! git branch -m master main

# %%
! git branch
# Out:
# * main

# %%
# !git remote -v
# Out:
# origin	https://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@github.com/dabhadepratik1/DataScience.git (fetch)
# origin	https://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@github.com/dabhadepratik1/DataScience.git (push)

# %%
! git status

# %%
! git add .

# %%
! git commit -m "initial commit"
# Out:
# [master e66e1ef] initial commit
#  1 file changed, 1 insertion(+), 1 deletion(-)

# %%
! git branch
# Out:
# * master

# %%
! git push -u origin master
# Out:
# fatal: could not read Password for 'https://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@github.com': No such device or address
