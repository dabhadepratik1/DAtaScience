# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
from sklearn.datasets import load_boston
#lib
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#read data set
df=pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Dataset/iris.csv")
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
# split data into traning and testing
# train_test_split
X=df[['sepal_length','sepal_width','petal_length','petal_width']]
y=df['species']

from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=1,stratify=y)

# %%
# create a model k=3,distance=manhatten_distance
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
ML_model=KNeighborsClassifier(n_neighbors=3,p=1)
print("model created")

#model traning
ML_model.fit(X_train,y_train)
print("model traning completed")

#find t y_pred
y_pred=ML_model.predict(X_test)
print("y_pred completed")

# find accuracy
acc=accuracy_score(y_test,y_pred)
print("ACC for =3:-",acc*100)

# confusion Matrix
from sklearn.metrics import confusion_matrix

cm=confusion_matrix(y_test,y_pred)
print(cm)

plt.figure(figsize=(10,6))
sns.heatmap(cm,annot=True)
plt.xlabel("Predicted")
plt.ylabel("Actual")
# Out:
# model created
# model traning completed
# y_pred completed
# ACC for =3:- 97.77777777777777
# [[15  0  0]
#  [ 0 15  0]
#  [ 0  1 14]]
# Text(69.0, 0.5, 'Actual')

# %%
from sklearn.feature_selection import mutual_info_classif
mutual_info=mutual_info_classif(X_train,y_train)
mutual_info
# Out:
# array([0.55211361, 0.30020946, 0.99266299, 0.95933219])

# %%
mutual_info_series=pd.Series(mutual_info)
mutual_info_series.index=X_train.columns
mutual_info_series
# Out:
# sepal_length    0.552114
# sepal_width     0.300209
# petal_length    0.992663
# petal_width     0.959332
# dtype: float64

# %%
mutual_info_series.sort_values(ascending=True)
# Out:
# sepal_width     0.300209
# sepal_length    0.552114
# petal_width     0.959332
# petal_length    0.992663
# dtype: float64

# %%
mutual_info_series.sort_values(ascending=False).plot.bar()

# %%
# ignore SW and train model

# %%
# split data into traning and testing
# train_test_split
X=df[['sepal_length','petal_length','petal_width']]
y=df['species']

from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=1,stratify=y)

# %%
# create a model k=3,distance=manhatten_distance
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
ML_model=KNeighborsClassifier(n_neighbors=3,p=1)
print("model created")

#model traning
ML_model.fit(X_train,y_train)
print("model traning completed")

#find t y_pred
y_pred=ML_model.predict(X_test)
print("y_pred completed")

# find accuracy
acc=accuracy_score(y_test,y_pred)
print("ACC for =3:-",acc*100)

# confusion Matrix
from sklearn.metrics import confusion_matrix

cm=confusion_matrix(y_test,y_pred)
print(cm)

plt.figure(figsize=(10,6))
sns.heatmap(cm,annot=True)
plt.xlabel("Predicted")
plt.ylabel("Actual")
# Out:
# model created
# model traning completed
# y_pred completed
# ACC for =3:- 95.55555555555556
# [[15  0  0]
#  [ 0 14  1]
#  [ 0  1 14]]
# Text(69.0, 0.5, 'Actual')
